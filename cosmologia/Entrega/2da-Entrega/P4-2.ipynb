# %%
import numpy as np
import pandas as pd

parametros = pd.read_csv('resultados_ajuste.csv', index_col = 0)

# %%
parametros
# Out:
#   Cantidad         Valor         error
# 0       H0  7.129061e-09  1.045078e-10
# 1       q0 -4.029466e-01  1.323646e-01

# %% [markdown]
# TEngo que hacer la integral con los resultados del ajuste
